# %% [markdown]
# Birden fazla bağımsız değişken

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# y = a0 + a1x ->linear regression

# %% [markdown]
# y = a0 + a1x1 + a2x2 +...+anxn ->multi variable linear regression
# y bağımlı değişken.
# x1 ve x2 bağımsız değişken

# %%
X = np.random.rand(100,2)
coef = np.array([3,5])
#y = 0 + np.dot(X,coef)
y = np.random.rand(100) + np.dot(X,coef)

# %%
''' fig = plt.figure()
ax = fig.add_subplot(111,projection = "3d")
ax.scatter(X[:,0],X[:,1],y)
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y") '''
# Out:
# ' fig = plt.figure()\nax = fig.add_subplot(111,projection = "3d")\nax.scatter(X[:,0],X[:,1],y)\nax.set_xlabel("X1")\nax.set_ylabel("X2")\nax.set_zlabel("y") '

# %%
lin_reg = LinearRegression()
lin_reg.fit(X,y)
fig = plt.figure()
ax = fig.add_subplot(111,projection = "3d")
ax.scatter(X[:,0],X[:,1],y)
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
#düzleştirmek için flatten kullanılır
x1, x2 = np.meshgrid(np.linspace(0,1,10),np.linspace(0,1,10))
y_pred = lin_reg.predict(np.array([x1.flatten(),x2.flatten()]).T)
ax.plot_surface(x1,x2,y_pred.reshape(x1.shape),alpha =0.3)
plt.title("multi veriable linear regression")
# Out:
# Text(0.5, 0.92, 'multi veriable linear regression')

# %%
print("Katsayilar: ", lin_reg.coef_)
print("Kesisim: ", lin_reg.intercept_)
# Out:
# Katsayilar:  [3.06433781 5.09382011]
# Kesisim:  0.41429957602286027
